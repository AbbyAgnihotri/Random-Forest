# %% [markdown]
# ## Random Forest - Fraud Check

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Fraud_check.csv")

# %%
df.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
df["Taxable.Income"] =(df["Taxable.Income"]<=30000).astype('int')

# %% [markdown]
# ### The above method converts taxable income to categories risky<=30000 i.e. 1 and rest to Good i.e. 0

# %%
df.isnull().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %% [markdown]
# ### Lets create dummy variable for categorical data

# %%
dummy_shel = pd.get_dummies(df["Marital.Status"])

# %%
df = pd.concat([df.drop("Marital.Status",axis=1),dummy_shel],axis=1)

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    Taxable.Income  City.Population  Work.Experience  Divorced  Married  \
# 0               0            50047               10         0        0
# 1               0           134075               18         1        0
# 2               0           160205               30         0        1
# 3               0           193264               15         0        0
# 4               0            27533               28         0        1
#
#    Single  Undergrad_YES  Urban_YES
# 0       1              0          1
# 1       0              1          1
# 2       0              0          1
# 3       1              1          1
# 4       0              0          0

# %%
X = df.drop("Taxable.Income",axis=1)
y = df["Taxable.Income"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
preds = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix,accuracy_score

# %%
plot_confusion_matrix(model,X_test,y_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86       144
#            1       0.00      0.00      0.00        36
#
#     accuracy                           0.76       180
#    macro avg       0.40      0.48      0.43       180
# weighted avg       0.63      0.76      0.69       180

# %%
from sklearn.model_selection import GridSearchCV

# %%
n_estimators=[64,100,120,150,180,200]
max_features= [2,3,4,5,6,7,8]
bootstrap = [True,False]
oob_score = [True,False]
criterion = ['gini','entropy']

# %%
param_grid = {'n_estimators':n_estimators,
              'criterion':criterion,
             'max_features':max_features,
             'bootstrap':bootstrap,
             'oob_score':oob_score}

# %%
rfc = RandomForestClassifier()
grid = GridSearchCV(rfc,param_grid)

# %%
grid.fit(X_train,y_train)
# Out:
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
# ...
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 352, in fit
#     raise ValueError("Out of bag estimation only available"
# ValueError: Out of bag estimation only available if bootstrap=True
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:619: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 393, in fit
#     for i, t in enumerate(trees))
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 1029, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 847, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 765, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\joblib\parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 171, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 907, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 289, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   FitFailedWarning)
# C:\Users\ABHAY\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:925: UserWarning: One or more of the test scores are non-finite: [0.74285714 0.72380952 0.75952381 0.73809524 0.74047619 0.73809524
#  0.74761905 0.73809524 0.7452381  0.7452381  0.74761905 0.7452381
#  0.76190476 0.74761905 0.74761905 0.7547619  0.75714286 0.75714286
#  0.77142857 0.74285714 0.75952381 0.75714286 0.75       0.7547619
#  0.7452381  0.77380952 0.76190476 0.75714286 0.76666667 0.75714286
#  0.76428571 0.7547619  0.75714286 0.76190476 0.75238095 0.76190476
#  0.76904762 0.75714286 0.75       0.75714286 0.75238095 0.75714286
#  0.7547619  0.76190476 0.75714286 0.75       0.76190476 0.75714286
#  0.75       0.76190476 0.7452381  0.75       0.75238095 0.75714286
#  0.74761905 0.74761905 0.7547619  0.75714286 0.75714286 0.75
#  0.75714286 0.74761905 0.7547619  0.75238095 0.75       0.75714286
#  0.75       0.7547619  0.75238095 0.7547619  0.75238095 0.75238095
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.74761905 0.74285714 0.75238095 0.75       0.74761905 0.74047619
#  0.74047619 0.74047619 0.74047619 0.73571429 0.73571429 0.74285714
#  0.74047619 0.74285714 0.75       0.74285714 0.7452381  0.74761905
#  0.75238095 0.75       0.76428571 0.75714286 0.75       0.7547619
#  0.76666667 0.76666667 0.7547619  0.75714286 0.7547619  0.7547619
#  0.75714286 0.75238095 0.7452381  0.75714286 0.76190476 0.75714286
#  0.74761905 0.74761905 0.7547619  0.75       0.7547619  0.75238095
#  0.75238095 0.75238095 0.7547619  0.7547619  0.75952381 0.75952381
#  0.76428571 0.76428571 0.75952381 0.75952381 0.76666667 0.75714286
#  0.75       0.75       0.75714286 0.75       0.76190476 0.75952381
#  0.75       0.73809524 0.7547619  0.76904762 0.7547619  0.75952381
#  0.74761905 0.75714286 0.75714286 0.75       0.74761905 0.75238095
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.7047619         nan 0.69761905        nan 0.69047619
#         nan 0.68571429        nan 0.69761905        nan 0.70238095
#         nan 0.71666667        nan 0.70952381        nan 0.70238095
#         nan 0.70952381        nan 0.70714286        nan 0.7
#         nan 0.69761905        nan 0.70714286        nan 0.7
#         nan 0.6952381         nan 0.69285714        nan 0.69285714
#         nan 0.68095238        nan 0.69047619        nan 0.68095238
#         nan 0.67857143        nan 0.68333333        nan 0.67857143
#         nan 0.65714286        nan 0.65238095        nan 0.65714286
#         nan 0.65952381        nan 0.65714286        nan 0.66190476
#         nan 0.63571429        nan 0.64047619        nan 0.63809524
#         nan 0.63571429        nan 0.63809524        nan 0.63809524
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.7               nan 0.69285714        nan 0.6952381
#         nan 0.69285714        nan 0.6952381         nan 0.7
#         nan 0.7047619         nan 0.70714286        nan 0.71190476
#         nan 0.70952381        nan 0.70238095        nan 0.7
#         nan 0.70238095        nan 0.69047619        nan 0.69047619
#         nan 0.70952381        nan 0.69285714        nan 0.6952381
#         nan 0.69047619        nan 0.68571429        nan 0.68809524
#         nan 0.68809524        nan 0.69047619        nan 0.69761905
#         nan 0.66666667        nan 0.66190476        nan 0.66428571
#         nan 0.65952381        nan 0.66190476        nan 0.65952381
#         nan 0.6452381         nan 0.63809524        nan 0.65
#         nan 0.63809524        nan 0.64285714        nan 0.64761905
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   category=UserWarning
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_features': [2, 3, 4, 5, 6, 7, 8],
#                          'n_estimators': [64, 100, 120, 150, 180, 200],
#                          'oob_score': [True, False]})

# %%
grid.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_features': 4,
#  'n_estimators': 64,
#  'oob_score': False}

# %%
predictions = grid.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87       144
#            1       0.25      0.06      0.09        36
#
#     accuracy                           0.78       180
#    macro avg       0.53      0.51      0.48       180
# weighted avg       0.69      0.78      0.72       180

# %%
plot_confusion_matrix(grid,X_test,y_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87       144
#            1       0.25      0.06      0.09        36
#
#     accuracy                           0.78       180
#    macro avg       0.53      0.51      0.48       180
# weighted avg       0.69      0.78      0.72       180

# %% [markdown]
# ### We see accuracy is improved but we may need more data w.r.t fraud to train our model for better prediction on fraud data detection.
